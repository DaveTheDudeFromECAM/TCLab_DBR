# %%
settings = 'ManFF'
if settings == 'Man':
    # OLP + no FF
    ManPath = (: True, 1000: False, 1500: True, TSim: True} # Path for Man
    MVManPath = {0: MV0 , Tsim : MV0} #path for MVMan
    
    # OLP + no FF
    
    
               
                 
                 
    SPPath = [e: PV0, TSim: MV0] # Path for SP, always the same in most cases
    DVPath = (e: 50.0, 800: 60, TSim: 60.0) # Path for DV
    ActivateFF    alse
    ManFF = True
    Title_lo0p = "Open-loop"
    Title FF = "no feedforward"
             
elif settings == 'ManFF":
    ManPath = {O: True,
    1000: False, 1500: True, TSim: True} # Path for Man
    MVManPath = (e: MV0, TSim: MV0} # Path for MVMan
    SPPath = (e: PVe, TSim: MV0} # Path for SP, always the same in most cases
    DVPath = {e: 50.0, see: 60,
    TSim: 60.0] # Path for DV
    ActivateFF = True
    ManFF = True
    T
    Title lo0p =
    "Open-loop"
    Title_FF
    "feedforward"
          
elif settings
== 'FF':
# FF,
CLP
ManPath = (e: True, 1000: False, 1500: True, TSim: True} # Path for Man
MVManPath
= {O: MVO, TSim: MV0] # Path for MVMan
SPPath = f0: PV0,
TSim:
MVO}
# Path for SP, always the same in most cases
DVPath = [e: 50.0, 800: 60, TSim: 60.0} # Path for DV
ActivateFF
n= True
ManFre talce
Title loop
=
"Closed-loop"
Title_FF
"feedforward'
Ace:
no FF.
CLP
ManPath = (©: True, 1000: False, 1500: True, TSim: True} # Path for Man
MVManPath = (e: MV0, TSim: MV0} # Path for MUMan
SPPath = (0: PVe,
TSim: MV0} # Path for SP, always the same in most cases
DVPath = (0: 50.0, 800: 60, TSim: 60.0) # Path for DV
ActivateFF = False
ManFF= False
Title loop =
"Closed-loop"
Title FF =
"no feedforward"
